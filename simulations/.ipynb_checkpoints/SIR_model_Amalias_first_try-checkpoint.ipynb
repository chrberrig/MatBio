# %%
# Import modules: 
from scipy.integrate import odeint
import matplotlib.pyplot as plt
import numpy as np

# %%
# Set-up font size for all the graphs:
fs_label = 20
parameters = {                
                'figure.titlesize': fs_label+6,
                'axes.labelsize': fs_label,
                'axes.titlesize': fs_label+4,
                'xtick.labelsize': fs_label,
                'ytick.labelsize': fs_label, 
                'legend.fontsize': fs_label
             }
plt.rcParams.update(parameters)

# %%
# Define a function with the three SIR equations:
def S_I_R(z, t, b, v):
    S = z[0]
    I = z[1]
    R = z[2]
    dSdt = -b * S * I
    dIdt = b * S * I - v * I
    dRdt = v * I
    dzdt = [dSdt, dIdt, dRdt]
    return dzdt

# %%
# Parameters

T = 14 # average period of infectivity 
S0 = 6*(10**6) # total susceptibles at the beginning of pandemic in Denmark
I0 = 15 # initial number of infected
R0 = 0
N0 = S0 + I0 + R0
z0 = [S0, I0, R0]
Q0 = 1.8 # reproductive number at the start of the pandemic in Denmark

v = 1/T # calculate recovery rate (v)
b = Q0 * v / S0 # calculate transmission rate (b) with data from the beginning of the pandemic

par = (b, v) # put parameters in a tuple to use in the ODE

t = np.linspace(0, 1000, 1001) # range for time 
# (I used 501 so that I get exactly 500 days as timesteps, without decimal points for timesteps)

# %%
# Solve the differential equation
ns = odeint(S_I_R, z0, t, args = par)

# %%
# Calculate outbreak numbers:
outbreak_start = np.amin(np.where(ns[:,1] > np.amax(ns[:,1])*0.01))
outbreak_end = np.amax(np.where(ns[:,1] > np.amax(ns[:,1])*0.01))
outbreak_peak = t[np.argmax(ns[:,1])] # when does it peak?
Imax = np.int(np.amax(ns[:,1])) # maximum infected
outbreak_duration = outbreak_end  - outbreak_start # how long does it last?
not_sick = np.int(np.amin(ns[:,0])) # number of susceptible people at equilibrium 
not_sick_percentage = np.round(100 * not_sick / N0, 2) # find the persentage of not sick and round to 2 decimals
equilibrium_start = np.amin(np.where(ns[:,0] < np.int((np.amin(ns[:,0]))+1))) # day when equations reach equilibrium

# %%
# Plot:
fig, ax = plt.subplots(figsize=(16,6), tight_layout=True)

ax.plot(t, ns[:,0], color = 'royalblue', label = 'Susceptibles', linewidth=4)
ax.plot(t, ns[:,1], color = 'lightcoral', label = 'Infected', linewidth=4)
ax.plot(t, ns[:,2], color = 'mediumseagreen', label = 'Immune', linewidth=4)

ax.axvline(outbreak_start, color='firebrick', linestyle=':', label='Outbreak begins')
ax.axvline(outbreak_end, color='cornflowerblue', linestyle=':', label='Outbreak ends')
ax.axvline(outbreak_peak, color='salmon', linestyle=':',linewidth=3, label='Outbreak peaks')

ax.ticklabel_format(useOffset=False, style='plain')
ax.set_xlabel('Time [days?]')
ax.set_ylabel('Number of individuals')
ax.legend(loc='upper center', bbox_to_anchor=(1.2, 1), borderaxespad=1)
ax.set_title('Covid-19 Epidemic in Denmark')

print(f'Transmission rate β: {b}')
print(f'Epidemic peaks at {np.int(outbreak_peak)} days with {Imax} persons infected per day. (Day 0 is at the initial 15 infections)')
print(f'Epidemic lasts {outbreak_duration} days (I > 0.01 of Imax)')
print(f'{not_sick} persons did not get sick, i.e. {not_sick_percentage}% of the Danish population')
# Out:
# Transmission rate β: 2.1428571428571426e-08
# Epidemic peaks at 218 days with 707363 persons infected per day. (Day 0 is at the initial 15 infections)
# Epidemic lasts 263 days (I > 0.01 of Imax)
# 1605406 persons did not get sick, i.e. 26.76% of the Danish population

# %%
# Plot:
fig, ax = plt.subplots(figsize=(15,5), tight_layout=True)

ax.plot(ns[:,0], ns[:,1], color = 'royalblue', linewidth=4)

ax.set_ylim(0, N0)
ax.set_xlim(0,N0)

ax.ticklabel_format(useOffset=False, style='plain')
ax.set_xlabel('Number of susceptibles')
ax.set_ylabel('Number of infected')
ax.set_title('Covid-19 Epidemic in Denmark,\nSusceptibles-Infected phase-space plot')

print(f'Transmission rate β: {b}')
print(f'Epidemic peaks at {np.int(outbreak_peak)} days with {Imax} persons infected per day. (Day 0 is at the initial 15 infections)')
print(f'Epidemic lasts {outbreak_duration} days (I > 0.01 of Imax)')
print(f'{not_sick} persons did not get sick, i.e. {not_sick_percentage}% of the Danish population')
# Out:
# Transmission rate β: 2.1428571428571426e-08
# Epidemic peaks at 218 days with 707363 persons infected per day. (Day 0 is at the initial 15 infections)
# Epidemic lasts 263 days (I > 0.01 of Imax)
# 1605406 persons did not get sick, i.e. 26.76% of the Danish population

# %%
b_incr = b + b*0.1
par = (b_incr, v)

# Solve the differential equation
ns = odeint(S_I_R, z0, t, args = par)

# Calculate outbreak numbers:
outbreak_start = np.amin(np.where(ns[:,1] > np.amax(ns[:,1])*0.01))
outbreak_end = np.amax(np.where(ns[:,1] > np.amax(ns[:,1])*0.01))
outbreak_peak = t[np.argmax(ns[:,1])] # when does it peak?
Imax = np.int(np.amax(ns[:,1])) # maximum infected
outbreak_duration = outbreak_end  - outbreak_start # how long does it last?
not_sick = np.int(np.amin(ns[:,0])) # number of susceptible people at equilibrium 
not_sick_percentage = np.round(100 * not_sick / N0, 2) # find the persentage of not sick and round to 2 decimals
equilibrium_start = np.amin(np.where(ns[:,0] < np.int((np.amin(ns[:,0]))+1))) # day when equations reach equilibrium

# Plot:
fig, ax = plt.subplots(figsize=(16,6), tight_layout=True)

ax.plot(t, ns[:,0], color = 'royalblue', label = 'Susceptibles', linewidth=4)
ax.plot(t, ns[:,1], color = 'lightcoral', label = 'Infected', linewidth=4)
ax.plot(t, ns[:,2], color = 'mediumseagreen', label = 'Immune', linewidth=4)

ax.axvline(outbreak_start, color='firebrick', linestyle=':', label='Outbreak begins')
ax.axvline(outbreak_end, color='cornflowerblue', linestyle=':', label='Outbreak ends')
ax.axvline(outbreak_peak, color='salmon', linestyle=':',linewidth=3, label='Outbreak peaks')

print(f'Transmission rate β: {b_incr}')
print(f'Epidemic peaks at {np.int(outbreak_peak)} days with {Imax} persons infected per day. (Day 0 is at the initial 15 infections)')
print(f'Epidemic lasts {outbreak_duration} days (I > 0.01 of Imax)')
print(f'{not_sick} persons did not get sick, i.e. {not_sick_percentage}% of the Danish population')
# Out:
# Transmission rate β: 2.3571428571428567e-08
# Epidemic peaks at 182 days with 899716 persons infected per day. (Day 0 is at the initial 15 infections)
# Epidemic lasts 224 days (I > 0.01 of Imax)
# 1252367 persons did not get sick, i.e. 20.87% of the Danish population

# %%
T = 14 # average period of infectivity 
# S0 = 6*(10**6) # total susceptibles at the beginning of pandemic in Denmark
I0 = np.arange(1,16) # range for initial number of infected
# R0 = 0
# N0 = S0 + I0 + R0
# z0 = [S0, I0, R0]
Q0 = 1.8 # reproductive number at the start of the pandemic in Denmark
v = 1/T # calculate recovery rate (v)

# b = Q0 * v / S0 # calculate transmission rate (b) with data from the beginning of the pandemic

# par = (b, v) # put parameters in a tuple to use in the ODE

t = np.linspace(0, 1000, 1001) # range for time 
# (I used 501 so that I get exactly 500 days as timesteps, without decimal points for timesteps)


for i in range(0,len(I0)):
    S0 = 6*(10**6)
    R0 = 0
    N0 = S0 + I0[i] + R0
    z0 = [S0, I0[i], R0]
    b = Q0 * v / S0 # calculate transmission rate (b) with data from the beginning of the pandemic
    par = (b, v) # put parameters in a tuple to use in the ODE

    # Solve the differential equation
    ns = odeint(S_I_R, z0, t, args = par)
    
    # Calculate outbreak numbers:
    outbreak_start = np.amin(np.where(ns[:,1] > np.amax(ns[:,1])*0.01))
    outbreak_end = np.amax(np.where(ns[:,1] > np.amax(ns[:,1])*0.01))
    outbreak_peak = t[np.argmax(ns[:,1])] # when does it peak?
    Imax = np.int(np.amax(ns[:,1])) # maximum infected
    outbreak_duration = outbreak_end  - outbreak_start # how long does it last?
    not_sick = np.int(np.amin(ns[:,0])) # number of susceptible people at equilibrium 
    not_sick_percentage = np.round(100 * not_sick / N0, 2) # find the persentage of not sick and round to 2 decimals
    equilibrium_start = np.amin(np.where(ns[:,0] < np.int((np.amin(ns[:,0]))+1))) # day when equations reach equilibrium
    
    
    
    # Plot:
    fig, ax = plt.subplots(figsize=(16,6), tight_layout=True)

    ax.plot(t, ns[:,0], color = 'royalblue', label = 'Susceptibles', linewidth=4)
    ax.plot(t, ns[:,1], color = 'lightcoral', label = 'Infected', linewidth=4)
    ax.plot(t, ns[:,2], color = 'mediumseagreen', label = 'Immune', linewidth=4)

    ax.axvline(outbreak_start, color='firebrick', linestyle=':', label='Outbreak begins')
    ax.axvline(outbreak_end, color='cornflowerblue', linestyle=':', label='Outbreak ends')
    ax.axvline(outbreak_peak, color='salmon', linestyle=':',linewidth=3, label='Outbreak peaks')

    ax.ticklabel_format(useOffset=False, style='plain')
    ax.set_xlabel('Time [days?]')
    ax.set_ylabel('Number of individuals')
    ax.legend(loc='upper center', bbox_to_anchor=(1.2, 1), borderaxespad=1)
    ax.set_title(f'Covid-19 Epidemic in Denmark,\nInitial infections at time 0: {I0[i]}')
    
    plt.show()
    
        
    # Plot:
    fig, ax = plt.subplots(figsize=(11,6), tight_layout=True)
    ax.plot(ns[:,0], ns[:,1], color = 'royalblue', linewidth=4)
    ax.ticklabel_format(useOffset=False, style='plain')
    ax.set_xlabel('Number of susceptibles')
    ax.set_ylabel('Number of infected')
    ax.set_title(f'Covid-19 Epidemic in Denmark,\nSusceptibles-Infected phase-space plot,\nInitial infections at time 0: {I0[i]}')
    plt.show()

    
    print(f'Epidemic peaks at {np.int(outbreak_peak)} days with {Imax} persons infected per day. (Day 0 is at the initial {I0[i]} infections)')
    print(f'Epidemic lasts {outbreak_duration} days (I > 0.01 of Imax)')
    print(f'{not_sick} persons did not get sick, i.e. {not_sick_percentage}% of the Danish population')
# Out:
# Epidemic peaks at 265 days with 707373 persons infected per day. (Day 0 is at the initial 1 infections)
# Epidemic lasts 262 days (I > 0.01 of Imax)
# 1605419 persons did not get sick, i.e. 26.76% of the Danish population
# Epidemic peaks at 253 days with 707379 persons infected per day. (Day 0 is at the initial 2 infections)
# Epidemic lasts 262 days (I > 0.01 of Imax)
# 1605418 persons did not get sick, i.e. 26.76% of the Danish population
# Epidemic peaks at 246 days with 707376 persons infected per day. (Day 0 is at the initial 3 infections)
# Epidemic lasts 262 days (I > 0.01 of Imax)
# 1605417 persons did not get sick, i.e. 26.76% of the Danish population
# Epidemic peaks at 241 days with 707374 persons infected per day. (Day 0 is at the initial 4 infections)
# Epidemic lasts 263 days (I > 0.01 of Imax)
# 1605416 persons did not get sick, i.e. 26.76% of the Danish population
# Epidemic peaks at 237 days with 707381 persons infected per day. (Day 0 is at the initial 5 infections)
# Epidemic lasts 262 days (I > 0.01 of Imax)
# 1605415 persons did not get sick, i.e. 26.76% of the Danish population
# Epidemic peaks at 234 days with 707362 persons infected per day. (Day 0 is at the initial 6 infections)
# Epidemic lasts 263 days (I > 0.01 of Imax)
# 1605414 persons did not get sick, i.e. 26.76% of the Danish population
# Epidemic peaks at 231 days with 707383 persons infected per day. (Day 0 is at the initial 7 infections)
# Epidemic lasts 262 days (I > 0.01 of Imax)
# 1605413 persons did not get sick, i.e. 26.76% of the Danish population
# Epidemic peaks at 229 days with 707357 persons infected per day. (Day 0 is at the initial 8 infections)
# Epidemic lasts 263 days (I > 0.01 of Imax)
# 1605412 persons did not get sick, i.e. 26.76% of the Danish population
# Epidemic peaks at 227 days with 707344 persons infected per day. (Day 0 is at the initial 9 infections)
# Epidemic lasts 263 days (I > 0.01 of Imax)
# 1605411 persons did not get sick, i.e. 26.76% of the Danish population
# Epidemic peaks at 225 days with 707375 persons infected per day. (Day 0 is at the initial 10 infections)
# Epidemic lasts 263 days (I > 0.01 of Imax)
# 1605410 persons did not get sick, i.e. 26.76% of the Danish population
# Epidemic peaks at 223 days with 707379 persons infected per day. (Day 0 is at the initial 11 infections)
# Epidemic lasts 262 days (I > 0.01 of Imax)
# 1605409 persons did not get sick, i.e. 26.76% of the Danish population
# Epidemic peaks at 222 days with 707337 persons infected per day. (Day 0 is at the initial 12 infections)
# Epidemic lasts 263 days (I > 0.01 of Imax)
# 1605409 persons did not get sick, i.e. 26.76% of the Danish population
# Epidemic peaks at 220 days with 707370 persons infected per day. (Day 0 is at the initial 13 infections)
# Epidemic lasts 262 days (I > 0.01 of Imax)
# 1605408 persons did not get sick, i.e. 26.76% of the Danish population
# Epidemic peaks at 219 days with 707390 persons infected per day. (Day 0 is at the initial 14 infections)
# Epidemic lasts 262 days (I > 0.01 of Imax)
# 1605407 persons did not get sick, i.e. 26.76% of the Danish population
# Epidemic peaks at 218 days with 707363 persons infected per day. (Day 0 is at the initial 15 infections)
# Epidemic lasts 263 days (I > 0.01 of Imax)
# 1605406 persons did not get sick, i.e. 26.76% of the Danish population

# %%
# # trying things out

# np.int(np.amax(ns[:,1])) # finds maximum of infected array
# np.argmax(ns[:,1]) # finds index of maximum of infected array
# t[np.argmax(ns[:,1])] # finds timepoint of maximum infected
# t[np.int(np.argmax(ns[:,1])*0.8)]
# np.amax(ns[:,1])
# np.amax(ns[:,1])*0.01
# np.where(np.amax(ns[:,1])*0.01)
# ns[:,1] > np.amax(ns[:,1])*0.01
# np.where(ns[:,1] > np.amax(ns[:,1])*0.01)
# np.amax(np.where(ns[:,1] > np.amax(ns[:,1])*0.01))
# np.amin(np.where(ns[:,1] > np.amax(ns[:,1])*0.01))
# ns[:,1][ns[:,1] > np.amax(ns[:,1])*0.01]
# np.int(np.amin(ns[:,0]))
# (ns[:,0] < np.int((np.amin(ns[:,0]))+1)).tolist() # find minimum numbers of susceptibles, make it integer, add one

# %%
# d. Intensive care

# Parameters
T = 14 # average period of infectivity 
S0 = 6*(10**6) # total susceptibles at the beginning of pandemic in Denmark
I0 = 15 # initial number of infected
R0 = 0
N0 = S0 + I0 + R0
z0 = [S0, I0, R0]
Q0 = 1.8 # reproductive number at the start of the pandemic in Denmark

v = 1/T # calculate recovery rate (v)
b = (Q0 * v / S0)*0.587 # calculate transmission rate (b) with data from the beginning of the pandemic

par = (b, v) # put parameters in a tuple to use in the ODE

t = np.linspace(0, 3000, 3001) # range for time 

# Solve the differential equation
ns = odeint(S_I_R, z0, t, args = par)

# Calculate outbreak numbers:
outbreak_start = np.amin(np.where(ns[:,1] > np.amax(ns[:,1])*0.01))
outbreak_end = np.amax(np.where(ns[:,1] > np.amax(ns[:,1])*0.01))
outbreak_peak = t[np.argmax(ns[:,1])] # when does it peak?
Imax = np.int(np.amax(ns[:,1])) # maximum infected
outbreak_duration = outbreak_end  - outbreak_start # how long does it last?
not_sick = np.int(np.amin(ns[:,0])) # number of susceptible people at equilibrium 
not_sick_percentage = np.round(100 * not_sick / N0, 2) # find the persentage of not sick and round to 2 decimals
equilibrium_start = np.amin(np.where(ns[:,0] < np.int((np.amin(ns[:,0]))+1))) # day when equations reach equilibrium

K = 900 # intensive care patient capacity
h = 0.1 # 10% of infected need intensive care

# Plot:
fig, ax = plt.subplots(figsize=(16,6), tight_layout=True)

ax.plot(t, ns[:,0], color = 'royalblue', label = 'Susceptibles', linewidth=4)
ax.plot(t, ns[:,1], color = 'lightcoral', label = 'Infected', linewidth=4)
ax.plot(t, ns[:,2], color = 'mediumseagreen', label = 'Immune', linewidth=4)

ax.axvline(outbreak_start, color='firebrick', linestyle=':', label='Outbreak begins')
ax.axvline(outbreak_end, color='cornflowerblue', linestyle=':', label='Outbreak ends')
ax.axvline(outbreak_peak, color='salmon', linestyle=':',linewidth=3, label='Outbreak peaks')
ax.axhline(I_K, color='red', linestyle=':',linewidth=3, label='Intensive care capacity')


ax.ticklabel_format(useOffset=False, style='plain')
ax.set_xlabel('Time [days?]')
ax.set_ylabel('Number of individuals')
ax.legend(loc='upper center', bbox_to_anchor=(1.2, 1), borderaxespad=1)
ax.set_title('Covid-19 Epidemic in Denmark')

print(f'Transmission rate β: {b}')
print(f'Epidemic peaks at {np.int(outbreak_peak)} days with {Imax} persons infected per day. (Day 0 is at the initial 15 infections)')
print(f'Epidemic lasts {outbreak_duration} days (I > 0.01 of Imax)')
print(f'{not_sick} persons did not get sick, i.e. {not_sick_percentage}% of the Danish population')

critically_ill = np.int(Imax * h)

if critically_ill <= K:
    print(f'All critically ill patients ({critically_ill}) can get intentsive care')
else:
    print(f'Not all critically ill patients ({critically_ill}) can get intensive care')
# Out:
# Transmission rate β: 1.2578571428571426e-08
# Epidemic peaks at 1924 days with 8781 persons infected per day. (Day 0 is at the initial 15 infections)
# Epidemic lasts 2562 days (I > 0.01 of Imax)
# 5377408 persons did not get sick, i.e. 89.62% of the Danish population
# All critically ill patients (878) can get intentsive care

# %%
# e. Loss of Immunity
# Define a function with the three SIR equations:
def S_I_R(z, t, b, v, g):
    S = z[0]
    I = z[1]
    R = z[2]
    dSdt = -b * S * I + g * R
    dIdt = b * S * I - v * I
    dRdt = v * I - g * R
    dzdt = [dSdt, dIdt, dRdt]
    return dzdt

# Parameters

T = 14 # average period of infectivity 
S0 = 6*(10**6) # total susceptibles at the beginning of pandemic in Denmark
I0 = 15 # initial number of infected
R0 = 0
N0 = S0 + I0 + R0
z0 = [S0, I0, R0]
Q0 = 1.8 # reproductive number at the start of the pandemic in Denmark

v = 1/T # calculate recovery rate (v)
b = (Q0 * v / S0) # calculate transmission rate (b) with data from the beginning of the pandemic
g = 0.005
par = (b, v, g) # put parameters in a tuple to use in the ODE

t = np.linspace(0, 3000, 3001) # range for time 

# Solve the differential equation
ns = odeint(S_I_R, z0, t, args = par)

# Calculate outbreak numbers:
outbreak_start = np.amin(np.where(ns[:,1] > np.amax(ns[:,1])*0.01))
outbreak_end = np.amax(np.where(ns[:,1] > np.amax(ns[:,1])*0.01))
outbreak_peak = t[np.argmax(ns[:,1])] # when does it peak?
Imax = np.int(np.amax(ns[:,1])) # maximum infected
outbreak_duration = outbreak_end  - outbreak_start # how long does it last?
not_sick = np.int(np.amin(ns[:,0])) # number of susceptible people at equilibrium 
not_sick_percentage = np.round(100 * not_sick / N0, 2) # find the persentage of not sick and round to 2 decimals
equilibrium_start = np.amin(np.where(ns[:,0] < np.int((np.amin(ns[:,0]))+1))) # day when equations reach equilibrium


# Plot:
fig, ax = plt.subplots(figsize=(16,6), tight_layout=True)

ax.plot(t, ns[:,0], color = 'royalblue', label = 'Susceptibles', linewidth=4)
ax.plot(t, ns[:,1], color = 'lightcoral', label = 'Infected', linewidth=4)
ax.plot(t, ns[:,2], color = 'mediumseagreen', label = 'Immune', linewidth=4)

ax.axvline(outbreak_start, color='firebrick', linestyle=':', label='Outbreak begins')
ax.axvline(outbreak_end, color='cornflowerblue', linestyle=':', label='Outbreak ends')
ax.axvline(outbreak_peak, color='salmon', linestyle=':',linewidth=3, label='Outbreak peaks')
ax.axhline(I_K, color='red', linestyle=':',linewidth=3, label='Intensive care capacity')


ax.ticklabel_format(useOffset=False, style='plain')
ax.set_xlabel('Time [days?]')
ax.set_ylabel('Number of individuals')
ax.legend(loc='upper center', bbox_to_anchor=(1.2, 1), borderaxespad=1)
ax.set_title('Covid-19 Epidemic in Denmark')

print(f'Transmission rate β: {b}')
print(f'Loss of immunity rate γ: {g}')
print(f'Epidemic peaks at {np.int(outbreak_peak)} days with {Imax} persons infected per day. (Day 0 is at the initial 15 infections)')
print(f'Epidemic lasts {outbreak_duration} days (I > 0.01 of Imax)')
print(f'{not_sick} persons did not get sick, i.e. {not_sick_percentage}% of the Danish population')

critically_ill = np.int(Imax * h)

if critically_ill <= K:
    print(f'All critically ill patients ({critically_ill}) can get intentsive care')
else:
    print(f'Not all critically ill patients ({critically_ill}) can get intensive care')
# Out:
# Transmission rate β: 2.1428571428571426e-08
# Loss of immunity rate γ: 0.005
# Epidemic peaks at 220 days with 761402 persons infected per day. (Day 0 is at the initial 15 infections)
# Epidemic lasts 2890 days (I > 0.01 of Imax)
# 2320780 persons did not get sick, i.e. 38.68% of the Danish population
# Not all critically ill patients (76140) can get intensive care

# %%
# f. Seasonality

# Define a function with the three SIR equations:
def S_I_R(z, t, v):
    b = (Q0 * v / S0)*(0.31*(np.sin(((t/365)*2*np.pi)+200)+2))
    S = z[0]
    I = z[1]
    R = z[2]
    dSdt = -b * S * I
    dIdt = b * S * I - v * I
    dRdt = v * I
    dzdt = [dSdt, dIdt, dRdt]
    return dzdt

t = np.linspace(0, 3000, 3001) # range for time 

# Parameters
T = 14 # average period of infectivity 
S0 = 6*(10**6) # total susceptibles at the beginning of pandemic in Denmark
I0 = 15 # initial number of infected
R0 = 0
N0 = S0 + I0 + R0
z0 = [S0, I0, R0]
Q0 = 1.8 # reproductive number at the start of the pandemic in Denmark

v = 1/T # calculate recovery rate (v)
 # calculate transmission rate (b) with data from the beginning of the pandemic

par = (v,) # put parameters in a tuple to use in the ODE



# Solve the differential equation
ns = odeint(S_I_R, z0, t, args = par)

# Calculate outbreak numbers:
outbreak_start = np.amin(np.where(ns[:,1] > np.amax(ns[:,1])*0.01))
outbreak_end = np.amax(np.where(ns[:,1] > np.amax(ns[:,1])*0.01))
outbreak_peak = t[np.argmax(ns[:,1])] # when does it peak?
Imax = np.int(np.amax(ns[:,1])) # maximum infected
outbreak_duration = outbreak_end  - outbreak_start # how long does it last?
not_sick = np.int(np.amin(ns[:,0])) # number of susceptible people at equilibrium 
not_sick_percentage = np.round(100 * not_sick / N0, 2) # find the persentage of not sick and round to 2 decimals
equilibrium_start = np.amin(np.where(ns[:,0] < np.int((np.amin(ns[:,0]))+1))) # day when equations reach equilibrium


# Plot:
fig, ax = plt.subplots(figsize=(16,6), tight_layout=True)

ax.plot(t, ns[:,0], color = 'royalblue', label = 'Susceptibles', linewidth=4)
ax.plot(t, ns[:,1], color = 'lightcoral', label = 'Infected', linewidth=4)
ax.plot(t, ns[:,2], color = 'mediumseagreen', label = 'Immune', linewidth=4)

ax.axvline(outbreak_start, color='firebrick', linestyle=':', label='Outbreak begins')
ax.axvline(outbreak_end, color='cornflowerblue', linestyle=':', label='Outbreak ends')
ax.axvline(outbreak_peak, color='salmon', linestyle=':',linewidth=3, label='Outbreak peaks')
ax.axhline(I_K, color='red', linestyle=':',linewidth=3, label='Intensive care capacity')


ax.ticklabel_format(useOffset=False, style='plain')
ax.set_xlabel('Time [days?]')
ax.set_ylabel('Number of individuals')
ax.legend(loc='upper center', bbox_to_anchor=(1.2, 1), borderaxespad=1)
ax.set_title('Covid-19 Epidemic in Denmark')

#print(f'Transmission rate β: {b}')
print(f'Epidemic peaks at {np.int(outbreak_peak)} days with {Imax} persons infected per day. (Day 0 is at the initial 15 infections)')
print(f'Epidemic lasts {outbreak_duration} days (I > 0.01 of Imax)')
print(f'{not_sick} persons did not get sick, i.e. {not_sick_percentage}% of the Danish population')

critically_ill = np.int(Imax * h)

if critically_ill <= K:
    print(f'All critically ill patients ({critically_ill}) can get intentsive care')
else:
    print(f'Not all critically ill patients ({critically_ill}) can get intensive care')
# Out:
# Epidemic peaks at 967 days with 100647 persons infected per day. (Day 0 is at the initial 15 infections)
# Epidemic lasts 1217 days (I > 0.01 of Imax)
# 4741049 persons did not get sick, i.e. 79.02% of the Danish population
# Not all critically ill patients (10064) can get intensive care

# %%
# g. perceived risk of infection

# Define a function with the three SIR equations:
def S_I_R(z, t, v):
    
    S = z[0]
    I = z[1]
    R = z[2]
    dSdt = -((Q0 * v / S0) * (I/np.square(I)*0.000001)) * S * I
    dIdt = ((Q0 * v / S0) * (I/np.square(I)*0.0000001)) * S * I - v * I
    dRdt = v * I
    dzdt = [dSdt, dIdt, dRdt]
    return dzdt

t = np.linspace(0, 3000, 3001) # range for time 

# Parameters
T = 14 # average period of infectivity 
S0 = 6*(10**6) # total susceptibles at the beginning of pandemic in Denmark
I0 = 15 # initial number of infected
R0 = 0
N0 = S0 + I0 + R0
z0 = [S0, I0, R0]
Q0 = 1.8 # reproductive number at the start of the pandemic in Denmark

v = 1/T # calculate recovery rate (v)
 # calculate transmission rate (b) with data from the beginning of the pandemic
# def b(I):
#     return((Q0 * v / S0) * I)

par = (v, ) # put parameters in a tuple to use in the ODE



# Solve the differential equation
ns = odeint(S_I_R, z0, t, args = par)

# Calculate outbreak numbers:
outbreak_start = np.amin(np.where(ns[:,1] > np.amax(ns[:,1])*0.01))
outbreak_end = np.amax(np.where(ns[:,1] > np.amax(ns[:,1])*0.01))
outbreak_peak = t[np.argmax(ns[:,1])] # when does it peak?
Imax = np.int(np.amax(ns[:,1])) # maximum infected
outbreak_duration = outbreak_end  - outbreak_start # how long does it last?
not_sick = np.int(np.amin(ns[:,0])) # number of susceptible people at equilibrium 
not_sick_percentage = np.round(100 * not_sick / N0, 2) # find the persentage of not sick and round to 2 decimals
equilibrium_start = np.amin(np.where(ns[:,0] < np.int((np.amin(ns[:,0]))+1))) # day when equations reach equilibrium


# Plot:
fig, ax = plt.subplots(figsize=(16,6), tight_layout=True)

ax.plot(t, ns[:,0], color = 'royalblue', label = 'Susceptibles', linewidth=4)
ax.plot(t, ns[:,1], color = 'lightcoral', label = 'Infected', linewidth=4)
ax.plot(t, ns[:,2], color = 'mediumseagreen', label = 'Immune', linewidth=4)

ax.axvline(outbreak_start, color='firebrick', linestyle=':', label='Outbreak begins')
ax.axvline(outbreak_end, color='cornflowerblue', linestyle=':', label='Outbreak ends')
ax.axvline(outbreak_peak, color='salmon', linestyle=':',linewidth=3, label='Outbreak peaks')
ax.axhline(I_K, color='red', linestyle=':',linewidth=3, label='Intensive care capacity')


ax.ticklabel_format(useOffset=False, style='plain')
ax.set_xlabel('Time [days?]')
ax.set_ylabel('Number of individuals')
ax.legend(loc='upper center', bbox_to_anchor=(1.2, 1), borderaxespad=1)
ax.set_title('Covid-19 Epidemic in Denmark')

#print(f'Transmission rate β: {b}')
print(f'Epidemic peaks at {np.int(outbreak_peak)} days with {Imax} persons infected per day. (Day 0 is at the initial 15 infections)')
print(f'Epidemic lasts {outbreak_duration} days (I > 0.01 of Imax)')
print(f'{not_sick} persons did not get sick, i.e. {not_sick_percentage}% of the Danish population')

critically_ill = np.int(Imax * h)

if critically_ill <= K:
    print(f'All critically ill patients ({critically_ill}) can get intentsive care')
else:
    print(f'Not all critically ill patients ({critically_ill}) can get intensive care')
# Out:
# Epidemic peaks at 0 days with 15 persons infected per day. (Day 0 is at the initial 15 infections)
# Epidemic lasts 64 days (I > 0.01 of Imax)
# 5999999 persons did not get sick, i.e. 100.0% of the Danish population
# All critically ill patients (1) can get intentsive care
