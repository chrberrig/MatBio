# %%
# Import stuff: 
from scipy.integrate import odeint
import matplotlib.pyplot as plt
import numpy as np

from sympy import Symbol
from sympy.solvers import solve

# This is for reasonable fontsize universally defined:
fs_label = 16
parameters = {                
                'figure.titlesize': fs_label+6,
                'axes.labelsize': fs_label,
                'axes.titlesize': fs_label+4,
                'xtick.labelsize': fs_label,
                'ytick.labelsize': fs_label, 
                'legend.fontsize': fs_label, 
                'lines.linewidth': 5,
                #'lines.marker':'o', 
                #'lines.markersize':4

             }
plt.rcParams.update(parameters)

# plt.rcParams.keys()

# We could also try with the colours:
#plt.rcParams['lines.color'] = 'r' # maybe here with more colours if needed?

# %%
# in this window, you put the correct parameters !!!
# phi = 25

# %%
#stages = 4
#shape = (stages, stages)
#L = np.zeros(shape)

L = np.array([
    [0,   0,       0,   25*0.8*1/4], 
    [0.8, 0.8*5/6, 0,   0], 
    [0,   0.8/6,   0,   0], 
    [0,   0,       0.8, 0.8*3/4]
])

# %%
# getting eigen vals + vects
eig_res = np.linalg.eig(L)
lams, vecs = eig_res
print(eig_res)

# getting only the dominatingeigen vals + corresponding eigrn vect.

id_max = max(enumerate([abs(x) for x in lams]), key=lambda x: x[1])[0] #gives index of max eigenvalue
lam_dom, vec_dom = lams[id_max], vecs[:, id_max]

#defining max growth-rate
r = np.log(lam_dom)
print(lam_dom, r)
vec_dom = vecs[:, 3]
print(vec_dom)
# Out:
# (array([-0.55151171+0.j        ,  0.31639741+0.74332683j,
#         0.31639741-0.74332683j,  1.18538356+0.j        ]), array([[ 0.8251643 +0.j        , -0.70714939+0.j        ,
#         -0.70714939-0.j        ,  0.53722406+0.j        ],
#        [-0.54190048+0.j        ,  0.29346462+0.62277838j,
#          0.29346462-0.62277838j,  0.828543  +0.j        ],
#        [ 0.13100972+0.j        ,  0.11354448-0.00430959j,
#          0.11354448+0.00430959j,  0.09319549+0.j        ],
#        [-0.09101755+0.j        , -0.04474805-0.10512862j,
#         -0.04474805+0.10512862j,  0.12736331+0.j        ]]))
# (1.185383560792695+0j) (0.17006640220786184+0j)
# [0.53722406+0.j 0.828543  +0.j 0.09319549+0.j 0.12736331+0.j]

# %%
def time_series(n0, t_end=10):
    ret = np.zeros((t_end, len(lams)))
    n = n0
    ret[0] = n0
    for t in range(1, t_end):
        n = np.matmul(L, n)
        ret[t] = n
    return ret


# Currently not used...

#V = vecs.T
#Vi = np.linalg.inv(V)
#print("V:")
#print(V)
#print("Vi:")
#print(Vi)

# evolve = lambda steps=1: V@np.diag([l**steps for l in lams])@Vi
# [matmul(evolve(i), n0) for i in range()]

# %%
t_end = 40
state_init = np.array([100, 0, 0, 0])
sim_res = time_series(state_init, t_end=t_end)
# eggs, larv, pupa, bug = sim_res.T
pop = np.sum(sim_res, axis=1)
growth = pop[1:]/pop[:-1]
proportions = np.array([s/np.sum(s) for s in sim_res])
# print(proportions)

# %%
t = np.arange(t_end)
discrete_style = {"linestyle":None, "linewidth":0, "marker":'o', "markersize":6}
labels = ["Eggs", "Larvae", "Pupa", "Bug"]

fig, ax = plt.subplots(figsize=(12, 6))
for i, state in enumerate(sim_res.T):
    ax.plot(t, state, label=labels[i], **discrete_style) 

# use this to plot analytical solutions:
#inits = [c[-1]*np.exp(-r*t)[-1] for c in sim_res.T]
#for i, c in enumerate(sim_res.T):
#    ax.plot(t, inits[i]*np.exp(r*t), label="", alpha=0.5)

ax.plot(t, pop, label="Population (Computed)", **discrete_style)
ax.plot(t, pop[0]*np.exp(r*t), label="Population (Assymptotic solution, Forward)", color="blue", alpha=0.5, linestyle=":")
ax.plot(t, pop[-1]*np.exp(-r*t)[::-1], label="Population (Assymptotic solution)", color="red", alpha=0.5, linestyle=":")

# ax.set_yscale("log")
ax.legend()
ax.set_xlabel("Time [15 days]")

# plt.savefig("timeseries.pdf")
# Out:
# /usr/lib/python3/dist-packages/numpy/core/_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# /usr/lib/python3/dist-packages/numpy/core/_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# Text(0.5, 0, 'Time [15 days]')

# %%
end_tmp = 5

fig, ax = plt.subplots(figsize=(12, 6))
for i, state in enumerate(sim_res.T):
    ax.plot(t[:end_tmp], state[:end_tmp], label=labels[i], **discrete_style) 

# use this to plot analytical solutions:
#inits = [c[-1]*np.exp(-r*t)[-1] for c in sim_res.T]
#for i, c in enumerate(sim_res.T):
#    ax.plot(t, inits[i]*np.exp(r*t), label="", alpha=0.5)

ax.plot(t[:end_tmp], pop[:end_tmp], label="Population (Computed)", **discrete_style)
ax.plot(t[:end_tmp], pop[0]*np.exp(r*t)[:end_tmp], label="Population (Assymptotic solution, Forward)", color="blue", alpha=0.5, linestyle=":")
ax.plot(t[:end_tmp], pop[-1]*np.exp(-r*t)[::-1][:end_tmp], label="Population (Assymptotic solution)", color="red", alpha=0.5, linestyle=":")

# ax.set_yscale("log")
ax.legend()
ax.set_xlabel("Time [15 days]")
# Out:
# /usr/lib/python3/dist-packages/numpy/core/_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# /usr/lib/python3/dist-packages/numpy/core/_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# Text(0.5, 0, 'Time [15 days]')

# %%
fig, ax = plt.subplots(figsize=(12, 6))
ax.plot(t[1:], growth, label="Growth pr. \"generation\" (Computed)", alpha=0.7, linestyle="--", marker="+", markersize=17)
ax.axhline(lam_dom, label="Growth pr. \"generation\" (Dominant Eigen Val.)", alpha=0.5, color="magenta")

ax.legend()
ax.set_xlabel("Time [15 days]")

fig, ax = plt.subplots(figsize=(12, 6))
ax.plot(t[1:], np.log(growth), label="Growth rate $r$ (Computed)", alpha=0.7, linestyle="--", marker="+", markersize=17)
ax.axhline(r, label="Growth rate $r$ (Assymptotic)", alpha=0.5, color="magenta")

ax.legend()
ax.set_xlabel("Time [15 days]")

fig, ax = plt.subplots(figsize=(12, 6))

for i, v in enumerate(vec_dom):
    num_prop = ax.plot(t, np.array(proportions).T[i], label=labels[i]+" (numeric)")
    ax.axhline(v/sum(vec_dom), alpha=0.5, linestyle=":", color=num_prop[0].get_color(), label=labels[i]+" (eigenvector component)")

ax.legend()
ax.set_xlabel("Time [15 days]")

# disregard warning, imaginary part is zero...
# Out:
# /usr/lib/python3/dist-packages/numpy/core/_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# /usr/lib/python3/dist-packages/numpy/core/_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# /usr/lib/python3/dist-packages/numpy/core/_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# /usr/lib/python3/dist-packages/numpy/core/_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# /usr/lib/python3/dist-packages/numpy/core/_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# /usr/lib/python3/dist-packages/numpy/core/_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# Text(0.5, 0, 'Time [15 days]')

# %%
# Not yet done, working on density dep.

#This defines the fecundity:
a = 1
# f = lambda N: 25*np.exp(-a*N)
f = lambda N: 25*(1/(1 + a*N))
#...and use this functional dependency in the "next-gen" matrix.
L = lambda N: np.array([
    [0,   0,       0,   f(N)*0.8*1/4], 
    [0.8, 0.8*5/6, 0,   0], 
    [0,   0.8*1/6, 0,   0], 
    [0,   0,       0.8, 0.8*3/4]
])

def time_series_density(n0, t_end=10):
    ret = np.zeros((t_end, len(lams)))
    n = n0
    for t in range(t_end):
        N = np.sum(n)
        n = np.matmul(L(N), n)
        ret[t] = n
    return ret

# %%
t_end = 40

state_init = np.array([100, 0, 0, 0])
sim_res = time_series_density(state_init, t_end=t_end)
# eggs, larv, pupa, bug = sim_res.T
pop = np.sum(sim_res, axis=1)
growth = pop[1:]/pop[:-1]
proportions = np.array([s/np.sum(s) for s in sim_res])

# %%
t = np.arange(t_end)
discrete_style = {"linestyle":None, "linewidth":0, "marker":'o', "markersize":6}
labels = ["Eggs", "Larvae", "Pupa", "Bug"]

fig, ax = plt.subplots(figsize=(12, 6))
for i, state in enumerate(sim_res.T):
    ax.plot(t, state, label=labels[i], **discrete_style) 

# use this to plot analytical solutions:
#inits = [c[-1]*np.exp(-r*t)[-1] for c in sim_res.T]
#for i, c in enumerate(sim_res.T):
#    ax.plot(t, inits[i]*np.exp(r*t), label="", alpha=0.5)

ax.plot(t, pop, label="Population (Computed)", **discrete_style)
ax.plot(t, pop[-1]*np.exp(-r*t)[::-1], label="Population (Assymptotic solution)", color="red", alpha=0.5, linestyle=":")

# ax.set_yscale("log")
ax.legend()
ax.set_xlabel("Time [15 days]")
# Out:
# /usr/lib/python3/dist-packages/numpy/core/_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# Text(0.5, 0, 'Time [15 days]')

# %%
# found the fecundity for eigenvalue=1, that is equilibrium condition.
f_star = (5*0.8-6)*(3*0.8-4)/(0.8**4)
L_star = np.array([
    [0,   0,       0,   f_star*0.8*1/4], 
    [0.8, 0.8*5/6, 0,   0], 
    [0,   0.8*1/6, 0,   0], 
    [0,   0,       0.8, 0.8*3/4]
])

e, v = np.linalg.eig(L_star)
e_dom, v_dom = e[3], v[:,3]

#confinrming the finding:
e_dom, v_dom
# Out:
# ((0.9999999999999997+0j),
#  array([0.37082847+0.j, 0.88998832+0.j, 0.11866511+0.j, 0.23733022+0.j]))

# %%
fig, ax = plt.subplots(figsize=(12, 6))
ax.plot(t[1:], growth, label="Growth pr. \"generation\" (Computed)", alpha=0.7, linestyle="--")
ax.axhline(1, label="Growth pr. \"generation\" (Dominant Eigen Val.)", alpha=0.7, linestyle=":", color="magenta")

ax.legend()
ax.set_xlabel("Time [15 days]")

fig, ax = plt.subplots(figsize=(12, 6))
ax.plot(t[1:], np.log(growth), label="Growth rate $r$ (Computed)", alpha=0.7, linestyle="--")
ax.axhline(0, label="Growth rate $r$ (Assymptotic)", alpha=0.7, linestyle=":", color="magenta")

ax.legend()
ax.set_xlabel("Time [15 days]")

fig, ax = plt.subplots(figsize=(12, 6))

for i, v in enumerate(v_dom):
    num_prop = ax.plot(t, np.array(proportions).T[i], label=labels[i]+" (numeric)")
    ax.axhline(v/sum(v_dom), alpha=0.5, linestyle=":", color=num_prop[0].get_color(), label=labels[i]+" (eigenvector component)")

ax.legend()
ax.set_xlabel("Time [15 days]")

# Note that we w densiy dependence reach equilibrium!
# Out:
# /usr/lib/python3/dist-packages/numpy/core/_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# /usr/lib/python3/dist-packages/numpy/core/_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# /usr/lib/python3/dist-packages/numpy/core/_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# /usr/lib/python3/dist-packages/numpy/core/_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# Text(0.5, 0, 'Time [15 days]')
